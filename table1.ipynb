# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

# %%
def get_pretty_pecent(a, b):
    #return round(100 * float(a)/float(b), 2)
    return "{:.2%}".format(a/b)
def get_chi(a, b):
    ctab = pd.crosstab(a, b)
    #print(ctab)
    chi2, p, dof, ex = chi2_contingency(ctab)
    if (p < 0.0005):
        p = '<0.0005';
    return p

# %%
data = pd.read_csv("./prepared_data.csv", index_col=False)

# %%
#get_chi(data['Period'], data['StageGroup'])

# %%
table = {
    'No':[
        len(data),
        '',
        len(data[data['Period']=='2007-2010']),
        len(data[data['Period']=='2011-2014']),
        len(data[data['Period']=='2015-2018']),
        '',
        len(data[data['AgeGroup']=='<= 29']),
        len(data[data['AgeGroup']=='30-44']),
        len(data[data['AgeGroup']=='45-59']),
        len(data[data['AgeGroup']=='60-74']),
        len(data[data['AgeGroup']=='>= 75']),
        '',
        len(data[data['Nationality']=='Estonian']),
        len(data[data['Nationality']=='Other']),
        len(data[data['Nationality'].isnull()]),
        '',
        len(data[data['Education']=='Basic&Primary']),
        len(data[data['Education']=='Secondary']),
        len(data[data['Education']=='Secondary_vocational']),
        len(data[data['Education']=='University&higher']),
        len(data[data['Education'].isnull()]),
        '',
        len(data[data['Marital Status']=='married']),
        len(data[data['Marital Status']=='divorced']),
        len(data[data['Marital Status']=='widow']),
        len(data[data['Marital Status']=='single']),
        len(data[data['Marital Status'].isnull()]),
        '',
        len(data[data['Residence']=='South']),
        len(data[data['Residence']=='North-East']),
        len(data[data['Residence']=='Central']),
        len(data[data['Residence']=='West']),
        len(data[data['Residence']=='North']),
        '',
        len(data[data['CodeGroup']=='SCC']),
        len(data[data['CodeGroup']=='AC']),
        len(data[data['CodeGroup'].isnull()]),
    ],
    ############ percent
    '%':[
        '100',
        '',
        get_pretty_pecent(len(data[data['Period']=='2007-2010']), len(data)),
        get_pretty_pecent(len(data[data['Period']=='2011-2014']), len(data)),
        get_pretty_pecent(len(data[data['Period']=='2015-2018']), len(data)),
        '',
        get_pretty_pecent(len(data[data['AgeGroup']=='<= 29']), len(data)),
        get_pretty_pecent(len(data[data['AgeGroup']=='30-44']), len(data)),
        get_pretty_pecent(len(data[data['AgeGroup']=='45-59']), len(data)),
        get_pretty_pecent(len(data[data['AgeGroup']=='60-74']), len(data)),
        get_pretty_pecent(len(data[data['AgeGroup']=='>= 75']), len(data)),
        '',
        get_pretty_pecent(len(data[data['Nationality']=='Estonian']), len(data)),
        get_pretty_pecent(len(data[data['Nationality']=='Other']), len(data)),
        get_pretty_pecent(len(data[data['Nationality'].isnull()]), len(data)),
        '',
        get_pretty_pecent(len(data[data['Education']=='Basic&Primary']), len(data)),
        get_pretty_pecent(len(data[data['Education']=='Secondary']), len(data)),
        get_pretty_pecent(len(data[data['Education']=='Secondary_vocational']), len(data)),
        get_pretty_pecent(len(data[data['Education']=='University&higher']), len(data)),
        get_pretty_pecent(len(data[data['Education'].isnull()]), len(data)),
        '',
        get_pretty_pecent(len(data[data['Marital Status']=='married']), len(data)),
        get_pretty_pecent(len(data[data['Marital Status']=='divorced']), len(data)),
        get_pretty_pecent(len(data[data['Marital Status']=='widow']), len(data)),
        get_pretty_pecent(len(data[data['Marital Status']=='single']), len(data)),
        get_pretty_pecent(len(data[data['Marital Status'].isnull()]), len(data)),
        '',
        get_pretty_pecent(len(data[data['Residence']=='South']), len(data)),
        get_pretty_pecent(len(data[data['Residence']=='North-East']), len(data)),
        get_pretty_pecent(len(data[data['Residence']=='Central']), len(data)),
        get_pretty_pecent(len(data[data['Residence']=='West']), len(data)),
        get_pretty_pecent(len(data[data['Residence']=='North']), len(data)),
        '',
        get_pretty_pecent(len(data[data['CodeGroup']=='SCC']), len(data)),
        get_pretty_pecent(len(data[data['CodeGroup']=='AC']), len(data)),
        get_pretty_pecent(len(data[data['CodeGroup'].isnull()]), len(data)),
    ],
    ######## early stage
   'Early':[
        len(data[data['StageGroup']==0]),
        '',
        len(data[(data['StageGroup']==0) & (data['Period']=='2007-2010')]),
        len(data[(data['StageGroup']==0) & (data['Period']=='2011-2014')]),
        len(data[(data['StageGroup']==0) & (data['Period']=='2015-2018')]),
        '',
        len(data[(data['StageGroup']==0) & (data['AgeGroup']=='<= 29')]),
        len(data[(data['StageGroup']==0) & (data['AgeGroup']=='30-44')]),
        len(data[(data['StageGroup']==0) & (data['AgeGroup']=='45-59')]),
        len(data[(data['StageGroup']==0) & (data['AgeGroup']=='60-74')]),
        len(data[(data['StageGroup']==0) & (data['AgeGroup']=='>= 75')]),   
        '',
        len(data[(data['StageGroup']==0) & (data['Nationality']=='Estonian')]),
        len(data[(data['StageGroup']==0) & (data['Nationality']=='Other')]),
        len(data[(data['StageGroup']==0) & (data['Nationality'].isnull())]),
        '',
        len(data[(data['StageGroup']==0) & (data['Education']=='Basic&Primary')]),
        len(data[(data['StageGroup']==0) & (data['Education']=='Secondary')]),
        len(data[(data['StageGroup']==0) & (data['Education']=='Secondary_vocational')]),
        len(data[(data['StageGroup']==0) & (data['Education']=='University&higher')]),
        len(data[(data['StageGroup']==0) & (data['Education'].isnull())]),
        '',
        len(data[(data['StageGroup']==0) & (data['Marital Status']=='married')]),
        len(data[(data['StageGroup']==0) & (data['Marital Status']=='divorced')]),
        len(data[(data['StageGroup']==0) & (data['Marital Status']=='widow')]),
        len(data[(data['StageGroup']==0) & (data['Marital Status']=='single')]),
        len(data[(data['StageGroup']==0) & (data['Marital Status'].isnull())]),
        '',
        len(data[(data['StageGroup']==0) & (data['Residence']=='South')]),
        len(data[(data['StageGroup']==0) & (data['Residence']=='North-East')]),
        len(data[(data['StageGroup']==0) & (data['Residence']=='Central')]),
        len(data[(data['StageGroup']==0) & (data['Residence']=='West')]),
        len(data[(data['StageGroup']==0) & (data['Residence']=='North')]),
        '',
        len(data[(data['StageGroup']==0) & (data['CodeGroup']=='SCC')]),
        len(data[(data['StageGroup']==0) & (data['CodeGroup']=='AC')]),
        len(data[(data['StageGroup']==0) & (data['CodeGroup'].isnull())]),
    ],
    ######## early stage %
   'Early, %':[
        get_pretty_pecent(len(data[data['StageGroup']==0]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Period']=='2007-2010')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Period']=='2011-2014')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Period']=='2015-2018')]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['AgeGroup']=='<= 29')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['AgeGroup']=='30-44')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['AgeGroup']=='45-59')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['AgeGroup']=='60-74')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['AgeGroup']=='>= 75')]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Nationality']=='Estonian')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Nationality']=='Other')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Nationality'].isnull())]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Education']=='Basic&Primary')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Education']=='Secondary')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Education']=='Secondary_vocational')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Education']=='University&higher')]),len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Education'].isnull())]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Marital Status']=='married')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Marital Status']=='divorced')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Marital Status']=='widow')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Marital Status']=='single')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Marital Status'].isnull())]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Residence']=='South')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Residence']=='North-East')]),len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Residence']=='Central')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Residence']=='West')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Residence']=='North')]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['CodeGroup']=='SCC')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['CodeGroup']=='AC')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['CodeGroup'].isnull())]), len(data)),
    ],
    ########### Advanced
   'Advanced':[
        len(data[data['StageGroup']==1]),
        '',
        len(data[(data['StageGroup']==1) & (data['Period']=='2007-2010')]),
        len(data[(data['StageGroup']==1) & (data['Period']=='2011-2014')]),
        len(data[(data['StageGroup']==1) & (data['Period']=='2015-2018')]),
        '',
        len(data[(data['StageGroup']==1) & (data['AgeGroup']=='<= 29')]),
        len(data[(data['StageGroup']==1) & (data['AgeGroup']=='30-44')]),
        len(data[(data['StageGroup']==1) & (data['AgeGroup']=='45-59')]),
        len(data[(data['StageGroup']==1) & (data['AgeGroup']=='60-74')]),
        len(data[(data['StageGroup']==1) & (data['AgeGroup']=='>= 75')]),   
        '',
        len(data[(data['StageGroup']==1) & (data['Nationality']=='Estonian')]),
        len(data[(data['StageGroup']==1) & (data['Nationality']=='Other')]),
        len(data[(data['StageGroup']==1) & (data['Nationality'].isnull())]),
        '',
        len(data[(data['StageGroup']==1) & (data['Education']=='Basic&Primary')]),
        len(data[(data['StageGroup']==1) & (data['Education']=='Secondary')]),
        len(data[(data['StageGroup']==1) & (data['Education']=='Secondary_vocational')]),
        len(data[(data['StageGroup']==1) & (data['Education']=='University&higher')]),
        len(data[(data['StageGroup']==1) & (data['Education'].isnull())]),
        '',
        len(data[(data['StageGroup']==1) & (data['Marital Status']=='married')]),
        len(data[(data['StageGroup']==1) & (data['Marital Status']=='divorced')]),
        len(data[(data['StageGroup']==1) & (data['Marital Status']=='widow')]),
        len(data[(data['StageGroup']==1) & (data['Marital Status']=='single')]),
        len(data[(data['StageGroup']==1) & (data['Marital Status'].isnull())]),
        '',
        len(data[(data['StageGroup']==1) & (data['Residence']=='South')]),
        len(data[(data['StageGroup']==1) & (data['Residence']=='North-East')]),
        len(data[(data['StageGroup']==1) & (data['Residence']=='Central')]),
        len(data[(data['StageGroup']==1) & (data['Residence']=='West')]),
        len(data[(data['StageGroup']==1) & (data['Residence']=='North')]),
        '',
        len(data[(data['StageGroup']==1) & (data['CodeGroup']=='SCC')]),
        len(data[(data['StageGroup']==1) & (data['CodeGroup']=='AC')]),
        len(data[(data['StageGroup']==1) & (data['CodeGroup'].isnull())]),
    ],
    ######## advanced stage %
   'Advanced, %':[
        get_pretty_pecent(len(data[data['StageGroup']==1]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Period']=='2007-2010')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Period']=='2011-2014')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Period']=='2015-2018')]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['AgeGroup']=='<= 29')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['AgeGroup']=='30-44')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['AgeGroup']=='45-59')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['AgeGroup']=='60-74')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['AgeGroup']=='>= 75')]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Nationality']=='Estonian')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Nationality']=='Other')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Nationality'].isnull())]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Education']=='Basic&Primary')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Education']=='Secondary')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Education']=='Secondary_vocational')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Education']=='University&higher')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Education'].isnull())]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Marital Status']=='married')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Marital Status']=='divorced')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Marital Status']=='widow')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Marital Status']=='single')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Marital Status'].isnull())]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Residence']=='South')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Residence']=='North-East')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Residence']=='Central')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Residence']=='West')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Residence']=='North')]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['CodeGroup']=='SCC')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['CodeGroup']=='AC')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['CodeGroup'].isnull())]), len(data)),
    ],
    ########### Unknown
   'Unknown':[
        len(data[data['StageGroup'].isnull()]),
        '',
        len(data[(data['StageGroup'].isnull()) & (data['Period']=='2007-2010')]),
        len(data[(data['StageGroup'].isnull()) & (data['Period']=='2011-2014')]),
        len(data[(data['StageGroup'].isnull()) & (data['Period']=='2015-2018')]),
        '',
        len(data[(data['StageGroup'].isnull()) & (data['AgeGroup']=='<= 29')]),
        len(data[(data['StageGroup'].isnull()) & (data['AgeGroup']=='30-44')]),
        len(data[(data['StageGroup'].isnull()) & (data['AgeGroup']=='45-59')]),
        len(data[(data['StageGroup'].isnull()) & (data['AgeGroup']=='60-74')]),
        len(data[(data['StageGroup'].isnull()) & (data['AgeGroup']=='>= 75')]),   
        '',
        len(data[(data['StageGroup'].isnull()) & (data['Nationality']=='Estonian')]),
        len(data[(data['StageGroup'].isnull()) & (data['Nationality']=='Other')]),
        len(data[(data['StageGroup'].isnull()) & (data['Nationality'].isnull())]),
        '',
        len(data[(data['StageGroup'].isnull()) & (data['Education']=='Basic&Primary')]),
        len(data[(data['StageGroup'].isnull()) & (data['Education']=='Secondary')]),
        len(data[(data['StageGroup'].isnull()) & (data['Education']=='Secondary_vocational')]),
        len(data[(data['StageGroup'].isnull()) & (data['Education']=='University&higher')]),
        len(data[(data['StageGroup'].isnull()) & (data['Education'].isnull())]),
        '',
        len(data[(data['StageGroup'].isnull()) & (data['Marital Status']=='married')]),
        len(data[(data['StageGroup'].isnull()) & (data['Marital Status']=='divorced')]),
        len(data[(data['StageGroup'].isnull()) & (data['Marital Status']=='widow')]),
        len(data[(data['StageGroup'].isnull()) & (data['Marital Status']=='single')]),
        len(data[(data['StageGroup'].isnull()) & (data['Marital Status'].isnull())]),
        '',
        len(data[(data['StageGroup'].isnull()) & (data['Residence']=='South')]),
        len(data[(data['StageGroup'].isnull()) & (data['Residence']=='North-East')]),
        len(data[(data['StageGroup'].isnull()) & (data['Residence']=='Central')]),
        len(data[(data['StageGroup'].isnull()) & (data['Residence']=='West')]),
        len(data[(data['StageGroup'].isnull()) & (data['Residence']=='North')]),
        '',
        len(data[(data['StageGroup'].isnull()) & (data['CodeGroup']=='SCC')]),
        len(data[(data['StageGroup'].isnull()) & (data['CodeGroup']=='AC')]),
        len(data[(data['StageGroup'].isnull()) & (data['CodeGroup'].isnull())]),
    ],
    ########### Unknown %
   'Unknown, %':[
        get_pretty_pecent(len(data[data['StageGroup'].isnull()]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Period']=='2007-2010')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Period']=='2011-2014')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Period']=='2015-2018')]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['AgeGroup']=='<= 29')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['AgeGroup']=='30-44')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['AgeGroup']=='45-59')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['AgeGroup']=='60-74')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['AgeGroup']=='>= 75')]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Nationality']=='Estonian')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Nationality']=='Other')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Nationality'].isnull())]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Education']=='Basic&Primary')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Education']=='Secondary')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Education']=='Secondary_vocational')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Education']=='University&higher')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Education'].isnull())]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Marital Status']=='married')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Marital Status']=='divorced')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Marital Status']=='widow')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Marital Status']=='single')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Marital Status'].isnull())]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Residence']=='South')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Residence']=='North-East')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Residence']=='Central')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Residence']=='West')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['Residence']=='North')]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['CodeGroup']=='SCC')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['CodeGroup']=='AC')]), len(data)),
        get_pretty_pecent(len(data[(data['StageGroup'].isnull()) & (data['CodeGroup'].isnull())]), len(data)),
    ],
    'p-value':[
        '',
        get_chi(data['Period'], data['StageGroup']),
        '',
        '',
        '',
        get_chi(data['AgeGroup'], data['StageGroup']),
        '',
        '',
        '',
        '',
        '',
        get_chi(data['Nationality'], data['StageGroup']),
        '',
        '',
        '',
        get_chi(data['Education'], data['StageGroup']),
        '',
        '',
        '',
        '',
        '',
        get_chi(data['Marital Status'], data['StageGroup']),
        '',
        '',
        '',
        '',
        '',
        get_chi(data['Residence'], data['StageGroup']),
        '',
        '',
        '',
        '',
        '',
        get_chi(data['CodeGroup'], data['StageGroup']),
        '',
        '',
        '',
    ],
}

# %%
index_list = [
    'Total',
    'Period of Diagnosis',
    '    2007-2010',
    '    2011-2014',
    '    2015-2018',
    'Age of Diagnosis',
    '    <=29',
    '    30-44',
    '    45-59',
    '    60-74',
    '    >=75',
    'Nationality',
    '    Estonian',
    '    Other',
    '    Unknown',
    'Educational Level',
    '    Basic&Primary',
    '    Secondary',
    '    Secondary_vocational',
    '    University&higher',
    '    Unknown',
    'Marital Status',
    '    Married',
    '    Divorced',
    '    Widow',
    '    Single',
    '    Unknown',
    'Region of residence',
    '    South',
    '    North-East',
    '    Central',
    '    West',
    '    North',
    'Tumor Morphology',
    '    SCC',
    '    AC',
    '    Other',
]


df = pd.DataFrame(table, index=index_list)
print(df)
# Out:
#                             No       % Early Early, % Advanced Advanced, %  \
# Total                     2046     100   737   36.02%     1137      55.57%
# Period of Diagnosis
#     2007-2010              752  36.75%   305   14.91%      384      18.77%
#     2011-2014              725  35.43%   245   11.97%      421      20.58%
#     2015-2018              569  27.81%   187    9.14%      332      16.23%
# Age of Diagnosis
#     <=29                    65   3.18%    40    1.96%       17       0.83%
#     30-44                  482  23.56%   276   13.49%      181       8.85%
#     45-59                  734  35.87%   269   13.15%      415      20.28%
#     60-74                  502  24.54%   118    5.77%      336      16.42%
#     >=75                   263  12.85%    34    1.66%      188       9.19%
# Nationality
#     Estonian              1402  68.52%   514   25.12%      764      37.34%
#     Other                  630  30.79%   220   10.75%      363      17.74%
#     Unknown                 14   0.68%     3    0.15%       10       0.49%
# Educational Level
#     Basic&Primary          425  20.77%   114    5.57%      264      12.90%
#     Secondary              787  38.47%   284   13.88%      428      20.92%
#     Secondary_vocational   366  17.89%   148    7.23%      196       9.58%
#     University&higher      326  15.93%   158    7.72%      150       7.33%
#     Unknown                142   6.94%    33    1.61%       99       4.84%
# Marital Status
#     Married                619  30.25%   262   12.81%      315      15.40%
#     Divorced               577  28.20%   203    9.92%      335      16.37%
#     Widow                  422  20.63%   107    5.23%      260      12.71%
#     Single                 362  17.69%   144    7.04%      189       9.24%
#     Unknown                 66   3.23%    21    1.03%       38       1.86%
# Region of residence
#     South                  489  23.90%   192    9.38%      250      12.22%
#     North-East             243  11.88%    80    3.91%      142       6.94%
#     Central                247  12.07%    87    4.25%      127       6.21%
#     West                   281  13.73%    90    4.40%      155       7.58%
#     North                  786  38.42%   288   14.08%      463      22.63%
# Tumor Morphology
#     SCC                   1635  79.91%   604   29.52%      907      44.33%
#     AC                     277  13.54%   112    5.47%      148       7.23%
#     Other                  134   6.55%    21    1.03%       82       4.01%
#
#                          Unknown Unknown, %   p-value
# Total                        172      8.41%
# Period of Diagnosis                          0.003677
#     2007-2010                 63      3.08%
#     2011-2014                 59      2.88%
#     2015-2018                 50      2.44%
# Age of Diagnosis                              <0.0005
#     <=29                       8      0.39%
#     30-44                     25      1.22%
#     45-59                     50      2.44%
#     60-74                     48      2.35%
#     >=75                      41      2.00%
# Nationality                                  0.334272
#     Estonian                 124      6.06%
#     Other                     47      2.30%
#     Unknown                    1      0.05%
# Educational Level                             <0.0005
#     Basic&Primary             47      2.30%
#     Secondary                 75      3.67%
#     Secondary_vocational      22      1.08%
#     University&higher         18      0.88%
#     Unknown                   10      0.49%
# Marital Status                                <0.0005
#     Married                   42      2.05%
#     Divorced                  39      1.91%
#     Widow                     55      2.69%
#     Single                    29      1.42%
#     Unknown                    7      0.34%
# Region of residence                          0.258931
#     South                     47      2.30%
#     North-East                21      1.03%
#     Central                   33      1.61%
#     West                      36      1.76%
#     North                     35      1.71%
# Tumor Morphology                              0.38242
#     SCC                      124      6.06%
#     AC                        17      0.83%
#     Other                     31      1.52%

# %%
df.to_csv('table1.csv', index=True)
