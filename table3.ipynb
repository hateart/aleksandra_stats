# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

# %%
data = pd.read_csv("./prepared_data.csv", index_col=False)

# %%
#drop unknown and empty
data = data.drop(data[data['StageGroup'].isnull()].index)
len(data)
# Out:
# 1874

# %%
def get_pretty_pecent(a, b):
    if b > 0:
        return round(100 * float(a)/float(b), 2)
    return 0
    #return "{:.2%}".format(a/b)
def get_chi(a, b):
    ctab = pd.crosstab(a, b)
    #print(ctab)
    chi2, p, dof, ex = chi2_contingency(ctab)
    if (p < 0.0005):
        p = '<0.0005';
    return p

# %%
table = {
    'No':[
        len(data),
        '',
        len(data[data['AgeGroup']=='<= 29']),
        len(data[data['AgeGroup']=='30-44']),
        len(data[data['AgeGroup']=='45-59']),
        len(data[data['AgeGroup']=='60-74']),
        len(data[data['AgeGroup']=='>= 75']),
        '',
        len(data[data['Nationality']=='Estonian']),
        len(data[data['Nationality']=='Other']),
        '',
        len(data[data['Education']=='Basic&Primary']),
        len(data[data['Education']=='Secondary']),
        len(data[data['Education']=='Secondary_vocational']),
        len(data[data['Education']=='University&higher']),
        '',
        len(data[data['Marital Status']=='married']),
        len(data[data['Marital Status']=='divorced']),
        len(data[data['Marital Status']=='widow']),
        len(data[data['Marital Status']=='single']),
        '',
        len(data[data['Residence']=='South']),
        len(data[data['Residence']=='North-East']),
        len(data[data['Residence']=='Central']),
        len(data[data['Residence']=='West']),
        len(data[data['Residence']=='North']),
        '',
        len(data[data['CodeGroup']=='SCC']),
        len(data[data['CodeGroup']=='AC']),
        len(data[data['CodeGroup']=='Other']),
    ],
    ############ percent
    '%':[
        '100',
        '',
        get_pretty_pecent(len(data[data['AgeGroup']=='<= 29']), len(data)),
        get_pretty_pecent(len(data[data['AgeGroup']=='30-44']), len(data)),
        get_pretty_pecent(len(data[data['AgeGroup']=='45-59']), len(data)),
        get_pretty_pecent(len(data[data['AgeGroup']=='60-74']), len(data)),
        get_pretty_pecent(len(data[data['AgeGroup']=='>= 75']), len(data)),
        '',
        get_pretty_pecent(len(data[data['Nationality']=='Estonian']), len(data)),
        get_pretty_pecent(len(data[data['Nationality']=='Other']), len(data)),
        '',
        get_pretty_pecent(len(data[data['Education']=='Basic&Primary']), len(data)),
        get_pretty_pecent(len(data[data['Education']=='Secondary']), len(data)),
        get_pretty_pecent(len(data[data['Education']=='Secondary_vocational']), len(data)),
        get_pretty_pecent(len(data[data['Education']=='University&higher']), len(data)),
        '',
        get_pretty_pecent(len(data[data['Marital Status']=='married']), len(data)),
        get_pretty_pecent(len(data[data['Marital Status']=='divorced']), len(data)),
        get_pretty_pecent(len(data[data['Marital Status']=='widow']), len(data)),
        get_pretty_pecent(len(data[data['Marital Status']=='single']), len(data)),
        '',
        get_pretty_pecent(len(data[data['Residence']=='South']), len(data)),
        get_pretty_pecent(len(data[data['Residence']=='North-East']), len(data)),
        get_pretty_pecent(len(data[data['Residence']=='Central']), len(data)),
        get_pretty_pecent(len(data[data['Residence']=='West']), len(data)),
        get_pretty_pecent(len(data[data['Residence']=='North']), len(data)),
        '',
        get_pretty_pecent(len(data[data['CodeGroup']=='SCC']), len(data)),
        get_pretty_pecent(len(data[data['CodeGroup']=='AC']), len(data)),
        get_pretty_pecent(len(data[data['CodeGroup']=='Other']), len(data)),
    ],
    ######## early stage
   'Early':[
        len(data[data['StageGroup']==0]),
        '',
        len(data[(data['StageGroup']==0) & (data['AgeGroup']=='<= 29')]),
        len(data[(data['StageGroup']==0) & (data['AgeGroup']=='30-44')]),
        len(data[(data['StageGroup']==0) & (data['AgeGroup']=='45-59')]),
        len(data[(data['StageGroup']==0) & (data['AgeGroup']=='60-74')]),
        len(data[(data['StageGroup']==0) & (data['AgeGroup']=='>= 75')]),   
        '',
        len(data[(data['StageGroup']==0) & (data['Nationality']=='Estonian')]),
        len(data[(data['StageGroup']==0) & (data['Nationality']=='Other')]),
        '',
        len(data[(data['StageGroup']==0) & (data['Education']=='Basic&Primary')]),
        len(data[(data['StageGroup']==0) & (data['Education']=='Secondary')]),
        len(data[(data['StageGroup']==0) & (data['Education']=='Secondary_vocational')]),
        len(data[(data['StageGroup']==0) & (data['Education']=='University&higher')]),
        '',
        len(data[(data['StageGroup']==0) & (data['Marital Status']=='married')]),
        len(data[(data['StageGroup']==0) & (data['Marital Status']=='divorced')]),
        len(data[(data['StageGroup']==0) & (data['Marital Status']=='widow')]),
        len(data[(data['StageGroup']==0) & (data['Marital Status']=='single')]),
        '',
        len(data[(data['StageGroup']==0) & (data['Residence']=='South')]),
        len(data[(data['StageGroup']==0) & (data['Residence']=='North-East')]),
        len(data[(data['StageGroup']==0) & (data['Residence']=='Central')]),
        len(data[(data['StageGroup']==0) & (data['Residence']=='West')]),
        len(data[(data['StageGroup']==0) & (data['Residence']=='North')]),
        '',
        len(data[(data['StageGroup']==0) & (data['CodeGroup']=='SCC')]),
        len(data[(data['StageGroup']==0) & (data['CodeGroup']=='AC')]),
        len(data[(data['StageGroup']==0) & (data['CodeGroup']=='Other')]),
    ],
    ######## early stage %
   'Early, %':[
        get_pretty_pecent(len(data[data['StageGroup']==0]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['AgeGroup']=='<= 29')]), len(data[data['AgeGroup']=='<= 29'])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['AgeGroup']=='30-44')]), len(data[data['AgeGroup']=='30-44'])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['AgeGroup']=='45-59')]), len(data[data['AgeGroup']=='45-59'])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['AgeGroup']=='60-74')]), len(data[data['AgeGroup']=='60-74'])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['AgeGroup']=='>= 75')]), len(data[data['AgeGroup']=='>= 75'])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Nationality']=='Estonian')]), len(data[data['Nationality']=='Estonian'])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Nationality']=='Other')]),  len(data[data['Nationality']=='Other'])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Education']=='Basic&Primary')]), len(data[data['Education']=='Basic&Primary'])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Education']=='Secondary')]),  len(data[data['Education']=='Secondary'])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Education']=='Secondary_vocational')]),  len(data[data['Education']=='Secondary_vocational'])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Education']=='University&higher')]),  len(data[data['Education']=='University&higher'])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Marital Status']=='married')]),  len(data[data['Marital Status']=='married'])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Marital Status']=='divorced')]),  len(data[data['Marital Status']=='divorced'])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Marital Status']=='widow')]),  len(data[data['Marital Status']=='widow'])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Marital Status']=='single')]),  len(data[data['Marital Status']=='single'])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Residence']=='South')]), len(data[data['Residence']=='South'])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Residence']=='North-East')]),  len(data[data['Residence']=='North-East'])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Residence']=='Central')]),  len(data[data['Residence']=='Central'])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Residence']=='West')]), len(data[data['Residence']=='West'])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Residence']=='North')]),  len(data[data['Residence']=='North'])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['CodeGroup']=='SCC')]), len(data[data['CodeGroup']=='SCC'])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['CodeGroup']=='AC')]),  len(data[data['CodeGroup']=='AC'])),
       get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['CodeGroup']=='Other')]),  len(data[data['CodeGroup']=='Other'])),
    ],
    ########### Advanced
   'Advanced':[
        len(data[data['StageGroup']==1]),
        '',
        len(data[(data['StageGroup']==1) & (data['AgeGroup']=='<= 29')]),
        len(data[(data['StageGroup']==1) & (data['AgeGroup']=='30-44')]),
        len(data[(data['StageGroup']==1) & (data['AgeGroup']=='45-59')]),
        len(data[(data['StageGroup']==1) & (data['AgeGroup']=='60-74')]),
        len(data[(data['StageGroup']==1) & (data['AgeGroup']=='>= 75')]),   
        '',
        len(data[(data['StageGroup']==1) & (data['Nationality']=='Estonian')]),
        len(data[(data['StageGroup']==1) & (data['Nationality']=='Other')]),
        '',
        len(data[(data['StageGroup']==1) & (data['Education']=='Basic&Primary')]),
        len(data[(data['StageGroup']==1) & (data['Education']=='Secondary')]),
        len(data[(data['StageGroup']==1) & (data['Education']=='Secondary_vocational')]),
        len(data[(data['StageGroup']==1) & (data['Education']=='University&higher')]),
        '',
        len(data[(data['StageGroup']==1) & (data['Marital Status']=='married')]),
        len(data[(data['StageGroup']==1) & (data['Marital Status']=='divorced')]),
        len(data[(data['StageGroup']==1) & (data['Marital Status']=='widow')]),
        len(data[(data['StageGroup']==1) & (data['Marital Status']=='single')]),
        '',
        len(data[(data['StageGroup']==1) & (data['Residence']=='South')]),
        len(data[(data['StageGroup']==1) & (data['Residence']=='North-East')]),
        len(data[(data['StageGroup']==1) & (data['Residence']=='Central')]),
        len(data[(data['StageGroup']==1) & (data['Residence']=='West')]),
        len(data[(data['StageGroup']==1) & (data['Residence']=='North')]),
        '',
        len(data[(data['StageGroup']==1) & (data['CodeGroup']=='SCC')]),
        len(data[(data['StageGroup']==1) & (data['CodeGroup']=='AC')]),
        len(data[(data['StageGroup']==1) & (data['CodeGroup']=='Other')]),
    ],
    ######## advanced stage %
   'Advanced, %':[
        get_pretty_pecent(len(data[data['StageGroup']==1]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['AgeGroup']=='<= 29')]), len(data[data['AgeGroup']=='<= 29'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['AgeGroup']=='30-44')]), len(data[data['AgeGroup']=='30-44'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['AgeGroup']=='45-59')]), len(data[data['AgeGroup']=='45-59'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['AgeGroup']=='60-74')]), len(data[data['AgeGroup']=='60-74'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['AgeGroup']=='>= 75')]), len(data[data['AgeGroup']=='>= 75'])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Nationality']=='Estonian')]), len(data[data['Nationality']=='Estonian'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Nationality']=='Other')]), len(data[data['Nationality']=='Other'])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Education']=='Basic&Primary')]), len(data[data['Education']=='Basic&Primary'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Education']=='Secondary')]), len(data[data['Education']=='Secondary'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Education']=='Secondary_vocational')]), len(data[data['Education']=='Secondary_vocational'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Education']=='University&higher')]), len(data[data['Education']=='University&higher'])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Marital Status']=='married')]), len(data[data['Marital Status']=='married'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Marital Status']=='divorced')]),  len(data[data['Marital Status']=='divorced'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Marital Status']=='widow')]),  len(data[data['Marital Status']=='widow'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Marital Status']=='single')]),  len(data[data['Marital Status']=='single'])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Residence']=='South')]),  len(data[data['Residence']=='South'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Residence']=='North-East')]),  len(data[data['Residence']=='North-East'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Residence']=='Central')]), len(data[data['Residence']=='Central'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Residence']=='West')]), len(data[data['Residence']=='West'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Residence']=='North')]),  len(data[data['Residence']=='North'])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['CodeGroup']=='SCC')]),  len(data[data['CodeGroup']=='SCC'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['CodeGroup']=='AC')]),  len(data[data['CodeGroup']=='AC'])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['CodeGroup']=='Other')]),  len(data[data['CodeGroup']=='Other'])),
      
    ],
    'p-value':[
        '',
        get_chi(data['AgeGroup'], data['StageGroup']),
        '',
        '',
        '',
        '',
        '',
        get_chi(data['Nationality'].notna(), data['StageGroup']),
        '',
        '',
        get_chi(data['Education'].notna(), data['StageGroup']),
        '',
        '',
        '',
        '',
        get_chi(data['Marital Status'].notna(), data['StageGroup']),
        '',
        '',
        '',
        '',
        get_chi(data['Residence'], data['StageGroup']),
        '',
        '',
        '',
        '',
        '',
        get_chi(data['CodeGroup'], data['StageGroup']),
        '',
        '',
        '',
    ],

}

# %%
index_list = [
    'Total',
    'Age of Diagnosis',
    '    <=29',
    '    30-44',
    '    45-59',
    '    60-74',
    '    >=75',
    'Nationality',
    '    Estonian',
    '    Other',
    'Educational Level',
    '    Basic&Primary',
    '    Secondary',
    '    Secondary_vocational',
    '    University&higher',
    'Marital Status',
    '    Married',
    '    Divorced',
    '    Widow',
    '    Single',
    'Region of residence',
    '    South',
    '    North-East',
    '    Central',
    '    West',
    '    North',
    'Tumor Morphology',
    '    SCC',
    '    AC',
    '    Other',
]


df = pd.DataFrame(table, index=index_list)

# %%
print(df)
# Out:
#                             No      % Early Early, % Advanced Advanced, %  \
# Total                     1874    100   737    39.33     1137       60.67
# Age of Diagnosis
#     <=29                    57   3.04    40    70.18       17       29.82
#     30-44                  457  24.39   276    60.39      181       39.61
#     45-59                  684   36.5   269    39.33      415       60.67
#     60-74                  454  24.23   118    25.99      336       74.01
#     >=75                   222  11.85    34    15.32      188       84.68
# Nationality
#     Estonian              1278   68.2   514    40.22      764       59.78
#     Other                  583  31.11   220    37.74      363       62.26
# Educational Level
#     Basic&Primary          378  20.17   114    30.16      264       69.84
#     Secondary              712  37.99   284    39.89      428       60.11
#     Secondary_vocational   344  18.36   148    43.02      196       56.98
# ...

# %%
# data fro calc_poisson

# %%
df2 = df.assign(Univariate=[
    '', '', 
        
    '0.752993 (0.497755 - 1.139220)', #'<=29', 
    'ref', 
    '1.531887 (1.347455 - 1.741586)', #'45-59', 
    '1.868620 (1.647971 - 2.118812)', #'60-74', 
    '2.138276 (1.884512 - 2.425974)', #'>=75', 
    '', 
    
    'ref', 
    '1.038524 (0.961250 - 1.122045)', #'Other', 
    '', 
    
    
    '1.234172 (1.110810 - 1.371169)', #'Basic&Primary', 
    '1.062261 (0.959821  1.175558)', #'Secondary', 
    '1.006823 (0.890292  1.138596)', #'Secondary_vocational', 
    'ref', 
    '', 
    'ref',         
        
    '1.121873 (1.019434 - 1.234613)', #'Divorced', 
    '1.276472 (1.159971 - 1.404534)', #'Widow', 
    '1.022551 (0.909901 - 1.149227)', #'Single', 
    '', 
        
    '0.917411 (0.830730 - 1.013196)', #'South',
    '1.037486 (0.925998 - 1.162462)', #'North-East ', 
    '0.962617 (0.849996 - 1.090137)', #'Central', 
    '1.026136 (0.918516 - 1.146470)', #'West', 
    'ref', 
    '', 
    'ref',  
    '0.931369 (0.822497 - 1.054738)', #'AC', 
    '1.246575 (1.123869 - 1.382592)', #'Other', 
])
df2 = df2.assign(Multivariate=[
    '', '',     
        
    '0.726076 (0.246317 - 2.140231)', #'<=29', 
    'ref', 
    '1.558463 (1.132615 - 2.144351)', #'45-59', 
    '1.893070 (1.350289 - 2.140231)', #'60-74', 
    '2.141486 (1.024790 - 4.474751)', #'>=75', 
    '', 
    'ref', 
    '1.030042 (0.919917 - 1.153352)', #'Other', 
    '', 
    
    '1.289559 (1.096353 - 1.516808)', #'Basic&Primary', 
    '1.172572 (1.019428 - 1.348643)', #'Secondary', 
    '1.115385 (0.960531 - 1.295279)', #'Secondary_vocational', 
    'ref', 
    '', 
    'ref',
    '1.040811 (0.886638 - 1.221886)', #'Divorced', 
    '0.972097 (0.610700 - 1.547217)', #'Widow', 
    '1.156618 (0.792219 - 1.688564)', #'Single', 
    '',     
    
    '0.930252 (0.842651 - 1.027050)', #'South',
    '1.046865 (0.931355 - 1.176630)', #'North-East ', 
    '0.950089 (0.843398 - 1.070265)', #'Central',
    '0.995411 (0.889979 - 1.113414)', #'West',
    'ref', 
    '', 
    'ref', 
    
    '0.924502 (0.824332 - 1.036919)', #'AC', 
    '1.181045 (1.070797 - 1.302591)', #'Other', 
])

# %%
print(df2)
# Out:
#                             No      % Early Early, % Advanced Advanced, %  \
# Total                     1874    100   737    39.33     1137       60.67
# Age of Diagnosis
#     <=29                    57   3.04    40    70.18       17       29.82
#     30-44                  457  24.39   276    60.39      181       39.61
#     45-59                  684   36.5   269    39.33      415       60.67
#     60-74                  454  24.23   118    25.99      336       74.01
#     >=75                   222  11.85    34    15.32      188       84.68
# Nationality
#     Estonian              1278   68.2   514    40.22      764       59.78
#     Other                  583  31.11   220    37.74      363       62.26
# Educational Level
#     Basic&Primary          378  20.17   114    30.16      264       69.84
#     Secondary              712  37.99   284    39.89      428       60.11
#     Secondary_vocational   344  18.36   148    43.02      196       56.98
# ...

# %%
df2.to_csv('table3.csv', index=True)
