# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

# %%
data = pd.read_csv("./prepared_data.csv", index_col=False)

# %%
#drop unknown and empty
data = data.drop(data[data['StageGroup'].isnull()].index)

# %%
def get_pretty_pecent(a, b):
    if b > 0:
        return round(100 * float(a)/float(b), 2)
    return 0
    #return "{:.2%}".format(a/b)
def get_chi(a, b):
    ctab = pd.crosstab(a, b)
    #print(ctab)
    chi2, p, dof, ex = chi2_contingency(ctab)
    if (p < 0.0005):
        p = '<0.0005';
    return p

# %%
table = {
    'No':[
        len(data),
        '',
        len(data[data['AgeGroup']=='<= 29']),
        len(data[data['AgeGroup']=='30-44']),
        len(data[data['AgeGroup']=='45-59']),
        len(data[data['AgeGroup']=='60-74']),
        len(data[data['AgeGroup']=='>= 75']),
        '',
        len(data[data['Nationality']=='Estonian']),
        len(data[data['Nationality']=='Other']),
        '',
        len(data[data['Education']=='Basic&Primary']),
        len(data[data['Education']=='Secondary']),
        len(data[data['Education']=='Secondary_vocational']),
        len(data[data['Education']=='University&higher']),
        '',
        len(data[data['Marital Status']=='married']),
        len(data[data['Marital Status']=='divorced']),
        len(data[data['Marital Status']=='widow']),
        len(data[data['Marital Status']=='single']),
        '',
        len(data[data['Residence']=='South']),
        len(data[data['Residence']=='North-East']),
        len(data[data['Residence']=='Central']),
        len(data[data['Residence']=='West']),
        len(data[data['Residence']=='North']),
        '',
        len(data[data['CodeGroup']=='SCC']),
        len(data[data['CodeGroup']=='AC']),
    ],
    ############ percent
    '%':[
        '100',
        '',
        get_pretty_pecent(len(data[data['AgeGroup']=='<= 29']), len(data)),
        get_pretty_pecent(len(data[data['AgeGroup']=='30-44']), len(data)),
        get_pretty_pecent(len(data[data['AgeGroup']=='45-59']), len(data)),
        get_pretty_pecent(len(data[data['AgeGroup']=='60-74']), len(data)),
        get_pretty_pecent(len(data[data['AgeGroup']=='>= 75']), len(data)),
        '',
        get_pretty_pecent(len(data[data['Nationality']=='Estonian']), len(data)),
        get_pretty_pecent(len(data[data['Nationality']=='Other']), len(data)),
        '',
        get_pretty_pecent(len(data[data['Education']=='Basic&Primary']), len(data)),
        get_pretty_pecent(len(data[data['Education']=='Secondary']), len(data)),
        get_pretty_pecent(len(data[data['Education']=='Secondary_vocational']), len(data)),
        get_pretty_pecent(len(data[data['Education']=='University&higher']), len(data)),
        '',
        get_pretty_pecent(len(data[data['Marital Status']=='married']), len(data)),
        get_pretty_pecent(len(data[data['Marital Status']=='divorced']), len(data)),
        get_pretty_pecent(len(data[data['Marital Status']=='widow']), len(data)),
        get_pretty_pecent(len(data[data['Marital Status']=='single']), len(data)),
        '',
        get_pretty_pecent(len(data[data['Residence']=='South']), len(data)),
        get_pretty_pecent(len(data[data['Residence']=='North-East']), len(data)),
        get_pretty_pecent(len(data[data['Residence']=='Central']), len(data)),
        get_pretty_pecent(len(data[data['Residence']=='West']), len(data)),
        get_pretty_pecent(len(data[data['Residence']=='North']), len(data)),
        '',
        get_pretty_pecent(len(data[data['CodeGroup']=='SCC']), len(data)),
        get_pretty_pecent(len(data[data['CodeGroup']=='AC']), len(data)),
    ],
    ######## early stage
   'Early':[
        len(data[data['StageGroup']==0]),
        '',
        len(data[(data['StageGroup']==0) & (data['AgeGroup']=='<= 29')]),
        len(data[(data['StageGroup']==0) & (data['AgeGroup']=='30-44')]),
        len(data[(data['StageGroup']==0) & (data['AgeGroup']=='45-59')]),
        len(data[(data['StageGroup']==0) & (data['AgeGroup']=='60-74')]),
        len(data[(data['StageGroup']==0) & (data['AgeGroup']=='>= 75')]),   
        '',
        len(data[(data['StageGroup']==0) & (data['Nationality']=='Estonian')]),
        len(data[(data['StageGroup']==0) & (data['Nationality']=='Other')]),
        '',
        len(data[(data['StageGroup']==0) & (data['Education']=='Basic&Primary')]),
        len(data[(data['StageGroup']==0) & (data['Education']=='Secondary')]),
        len(data[(data['StageGroup']==0) & (data['Education']=='Secondary_vocational')]),
        len(data[(data['StageGroup']==0) & (data['Education']=='University&higher')]),
        '',
        len(data[(data['StageGroup']==0) & (data['Marital Status']=='married')]),
        len(data[(data['StageGroup']==0) & (data['Marital Status']=='divorced')]),
        len(data[(data['StageGroup']==0) & (data['Marital Status']=='widow')]),
        len(data[(data['StageGroup']==0) & (data['Marital Status']=='single')]),
        '',
        len(data[(data['StageGroup']==0) & (data['Residence']=='South')]),
        len(data[(data['StageGroup']==0) & (data['Residence']=='North-East')]),
        len(data[(data['StageGroup']==0) & (data['Residence']=='Central')]),
        len(data[(data['StageGroup']==0) & (data['Residence']=='West')]),
        len(data[(data['StageGroup']==0) & (data['Residence']=='North')]),
        '',
        len(data[(data['StageGroup']==0) & (data['CodeGroup']=='SCC')]),
        len(data[(data['StageGroup']==0) & (data['CodeGroup']=='AC')]),
    ],
    ######## early stage %
   'Early, %':[
        get_pretty_pecent(len(data[data['StageGroup']==0]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['AgeGroup']=='<= 29')]), len(data[(data['StageGroup']==0) & (data['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['AgeGroup']=='30-44')]), len(data[(data['StageGroup']==0) & (data['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['AgeGroup']=='45-59')]), len(data[(data['StageGroup']==0) & (data['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['AgeGroup']=='60-74')]), len(data[(data['StageGroup']==0) & (data['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['AgeGroup']=='>= 75')]), len(data[(data['StageGroup']==0) & (data['AgeGroup'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Nationality']=='Estonian')]), len(data[(data['StageGroup']==0) & (data['Nationality'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Nationality']=='Other')]), len(data[(data['StageGroup']==0) & (data['Nationality'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Education']=='Basic&Primary')]), len(data[(data['StageGroup']==0) & (data['Education'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Education']=='Secondary')]), len(data[(data['StageGroup']==0) & (data['Education'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Education']=='Secondary_vocational')]), len(data[(data['StageGroup']==0) & (data['Education'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Education']=='University&higher')]), len(data[(data['StageGroup']==0) & (data['Education'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Marital Status']=='married')]), len(data[(data['StageGroup']==0) & (data['Marital Status'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Marital Status']=='divorced')]), len(data[(data['StageGroup']==0) & (data['Marital Status'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Marital Status']=='widow')]), len(data[(data['StageGroup']==0) & (data['Marital Status'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Marital Status']=='single')]), len(data[(data['StageGroup']==0) & (data['Marital Status'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Residence']=='South')]), len(data[(data['StageGroup']==0) & (data['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Residence']=='North-East')]), len(data[(data['StageGroup']==0) & (data['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Residence']=='Central')]), len(data[(data['StageGroup']==0) & (data['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Residence']=='West')]), len(data[(data['StageGroup']==0) & (data['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['Residence']=='North')]), len(data[(data['StageGroup']==0) & (data['Residence'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['CodeGroup']=='SCC')]), len(data[(data['StageGroup']==0) & (data['CodeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==0) & (data['CodeGroup']=='AC')]), len(data[(data['StageGroup']==0) & (data['CodeGroup'].notna())])),
    ],
    ########### Advanced
   'Advanced':[
        len(data[data['StageGroup']==1]),
        '',
        len(data[(data['StageGroup']==1) & (data['AgeGroup']=='<= 29')]),
        len(data[(data['StageGroup']==1) & (data['AgeGroup']=='30-44')]),
        len(data[(data['StageGroup']==1) & (data['AgeGroup']=='45-59')]),
        len(data[(data['StageGroup']==1) & (data['AgeGroup']=='60-74')]),
        len(data[(data['StageGroup']==1) & (data['AgeGroup']=='>= 75')]),   
        '',
        len(data[(data['StageGroup']==1) & (data['Nationality']=='Estonian')]),
        len(data[(data['StageGroup']==1) & (data['Nationality']=='Other')]),
        '',
        len(data[(data['StageGroup']==1) & (data['Education']=='Basic&Primary')]),
        len(data[(data['StageGroup']==1) & (data['Education']=='Secondary')]),
        len(data[(data['StageGroup']==1) & (data['Education']=='Secondary_vocational')]),
        len(data[(data['StageGroup']==1) & (data['Education']=='University&higher')]),
        '',
        len(data[(data['StageGroup']==1) & (data['Marital Status']=='married')]),
        len(data[(data['StageGroup']==1) & (data['Marital Status']=='divorced')]),
        len(data[(data['StageGroup']==1) & (data['Marital Status']=='widow')]),
        len(data[(data['StageGroup']==1) & (data['Marital Status']=='single')]),
        '',
        len(data[(data['StageGroup']==1) & (data['Residence']=='South')]),
        len(data[(data['StageGroup']==1) & (data['Residence']=='North-East')]),
        len(data[(data['StageGroup']==1) & (data['Residence']=='Central')]),
        len(data[(data['StageGroup']==1) & (data['Residence']=='West')]),
        len(data[(data['StageGroup']==1) & (data['Residence']=='North')]),
        '',
        len(data[(data['StageGroup']==1) & (data['CodeGroup']=='SCC')]),
        len(data[(data['StageGroup']==1) & (data['CodeGroup']=='AC')]),
    ],
    ######## advanced stage %
   'Advanced, %':[
        get_pretty_pecent(len(data[data['StageGroup']==1]), len(data)),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['AgeGroup']=='<= 29')]), len(data[(data['StageGroup']==1) & (data['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['AgeGroup']=='30-44')]), len(data[(data['StageGroup']==1) & (data['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['AgeGroup']=='45-59')]), len(data[(data['StageGroup']==1) & (data['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['AgeGroup']=='60-74')]), len(data[(data['StageGroup']==1) & (data['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['AgeGroup']=='>= 75')]), len(data[(data['StageGroup']==1) & (data['AgeGroup'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Nationality']=='Estonian')]), len(data[(data['StageGroup']==1) & (data['Nationality'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Nationality']=='Other')]), len(data[(data['StageGroup']==1) & (data['Nationality'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Education']=='Basic&Primary')]), len(data[(data['StageGroup']==1) & (data['Education'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Education']=='Secondary')]), len(data[(data['StageGroup']==1) & (data['Education'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Education']=='Secondary_vocational')]), len(data[(data['StageGroup']==1) & (data['Education'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Education']=='University&higher')]), len(data[(data['StageGroup']==1) & (data['Education'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Marital Status']=='married')]), len(data[(data['StageGroup']==1) & (data['Marital Status'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Marital Status']=='divorced')]), len(data[(data['StageGroup']==1) & (data['Marital Status'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Marital Status']=='widow')]), len(data[(data['StageGroup']==1) & (data['Marital Status'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Marital Status']=='single')]), len(data[(data['StageGroup']==1) & (data['Marital Status'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Residence']=='South')]), len(data[(data['StageGroup']==1) & (data['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Residence']=='North-East')]), len(data[(data['StageGroup']==1) & (data['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Residence']=='Central')]), len(data[(data['StageGroup']==1) & (data['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Residence']=='West')]), len(data[(data['StageGroup']==1) & (data['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['Residence']=='North')]), len(data[(data['StageGroup']==1) & (data['Residence'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['CodeGroup']=='SCC')]), len(data[(data['StageGroup']==1) & (data['CodeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['StageGroup']==1) & (data['CodeGroup']=='AC')]), len(data[(data['StageGroup']==1) & (data['CodeGroup'].notna())])),
      
    ],
    'p-value':[
        '',
        get_chi(data['AgeGroup'], data['StageGroup']),
        '',
        '',
        '',
        '',
        '',
        get_chi(data['Nationality'].notna(), data['StageGroup']),
        '',
        '',
        get_chi(data['Education'].notna(), data['StageGroup']),
        '',
        '',
        '',
        '',
        get_chi(data['Marital Status'].notna(), data['StageGroup']),
        '',
        '',
        '',
        '',
        get_chi(data['Residence'], data['StageGroup']),
        '',
        '',
        '',
        '',
        '',
        get_chi(data['CodeGroup'].notna(), data['StageGroup']),
        '',
        '',
    ],

}

# %%
index_list = [
    'Total',
    'Age of Diagnosis',
    '    <=29',
    '    30-44',
    '    45-59',
    '    60-74',
    '    >=75',
    'Nationality',
    '    Estonian',
    '    Other',
    'Educational Level',
    '    Basic&Primary',
    '    Secondary',
    '    Secondary_vocational',
    '    University&higher',
    'Marital Status',
    '    Married',
    '    Divorced',
    '    Widow',
    '    Single',
    'Region of residence',
    '    South',
    '    North-East',
    '    Central',
    '    West',
    '    North',
    'Tumor Morphology',
    '    SCC',
    '    AC',
]


df = pd.DataFrame(table, index=index_list)

# %%
print(df)
# Out:
#                             No      % Early Early, % Advanced Advanced, %  \
# Total                     1874    100   737    39.33     1137       60.67
# Age of Diagnosis
#     <=29                    57   3.04    40     5.43       17         1.5
#     30-44                  457  24.39   276    37.45      181       15.92
#     45-59                  684   36.5   269     36.5      415        36.5
#     60-74                  454  24.23   118    16.01      336       29.55
#     >=75                   222  11.85    34     4.61      188       16.53
# Nationality
#     Estonian              1278   68.2   514    70.03      764       67.79
#     Other                  583  31.11   220    29.97      363       32.21
# Educational Level
#     Basic&Primary          378  20.17   114    16.19      264       25.43
#     Secondary              712  37.99   284    40.34      428       41.23
#     Secondary_vocational   344  18.36   148    21.02      196       18.88
# ...

# %%
# data fro calc_poisson

# %%
df2 = df.assign(Univariate=[
    '', '', 
    '0.653704 (0.402746 - 1.060945)', #'<=29', 
    'ref', 
    '1.500202 (1.307040 - 1.722069)', #'45-59', 
    '1.860044 (1.624974 - 2.129150)', #'60-74', 
    '2.154158 (1.879769 - 2.468490)', #'>=75', 
    '', 
    'ref', 

    '1.050851 (0.963517 - 1.146175)', #'Other', 
    '', 
    '1.433473 (1.244224 - 1.651638)', #'Basic&Primary', 
    '1.236642 (1.077502  1.419210)', #'Secondary', 
    '1.154422 (0.986985  1.350242)', #'Secondary_vocational', 
    'ref', 
    '', 
    'ref',         
    '1.153153 (1.034395 - 1.285631)', #'Divorced', 
    '1.305388 (1.168459 - 1.458327)', #'Widow', 
    '1.018570 (0.891349 - 1.163915)', #'Single', 
    '', 
    '0.918053 (0.820532 - 1.027187)', #'South',
    '1.030455 (0.905090 - 1.173084)', #'North-East ', 
    '0.945256 (0.820328 - 1.089111)', #'Central', 
    '1.052323 (0.930987 - 1.189521)', #'West', 
    'ref', 
    '', 
    'ref', 
    '0.969379 (0.860702 - 1.091868)', #'AC', 
])
df2 = df2.assign(Multivariate=[
    '', '',     
    '0.640568 (0.384475 - 1.067218)', #'<=29', 
    'ref', 
    '1.539565 (1.253613 - 1.8908209)', #'45-59', 
    '1.915924 (1.640012 - 2.238397)', #'60-74', 
    '2.193503 (1.871264 - 2.571463)', #'>=75', 
    '', 
    'ref', 
    '1.038731 (0.937311 - 1.151105)', #'Other', 
    '', 
        
    '1.288141 (1.116391 - 1.486417)', #'Basic&Primary', 
    '1.172690 (1.028781 - 1.336769)', #'Secondary', 
    '1.090679 (0.937969 - 1.268335)', #'Secondary_vocational', 
    'ref', 
    '', 
    'ref',
    '1.044460 (0.922762 - 1.182195)', #'Divorced', 
    '0.956380 (0.746197 - 1.225736)', #'Widow', 
    '1.143736 (0.957567 - 1.366189)', #'Single', 
    '',     
    '0.916952 (0.817249 - 1.028853)', #'South',
    '1.018570 (0.888979 - 1.167001)', #'North-East ', 
    '0.935663 (0.814784 - 1.074427)', #'Central',
    '1.017145 (0.900037 - 1.149492)', #'West',
    'ref', 
    '', 
    'ref', 
    '0.960213 (0.859308 - 1.073051)', #'AC', 
])

# %%
print(df2)
# Out:
#                             No      % Early Early, % Advanced Advanced, %  \
# Total                     1874    100   737    39.33     1137       60.67
# Age of Diagnosis
#     <=29                    57   3.04    40     5.43       17         1.5
#     30-44                  457  24.39   276    37.45      181       15.92
#     45-59                  684   36.5   269     36.5      415        36.5
#     60-74                  454  24.23   118    16.01      336       29.55
#     >=75                   222  11.85    34     4.61      188       16.53
# Nationality
#     Estonian              1278   68.2   514    70.03      764       67.79
#     Other                  583  31.11   220    29.97      363       32.21
# Educational Level
#     Basic&Primary          378  20.17   114    16.19      264       25.43
#     Secondary              712  37.99   284    40.34      428       41.23
#     Secondary_vocational   344  18.36   148    21.02      196       18.88
# ...

# %%
df2.to_csv('table3.csv', index=True)
