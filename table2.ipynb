# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

# %%
data = pd.read_csv("./prepared_data.csv", index_col=False)

# %%
def get_pretty_pecent(a, b):
    return round(100 * float(a)/float(b), 2)
    #return "{:.2%}".format(a/b)
def get_chi(a, b):
    ctab = pd.crosstab(a, b)
    #print(ctab)
    chi2, p, dof, ex = chi2_contingency(ctab)
    if (p < 0.0005):
        p = '<0.0005';
    return p

# %%
#drop unknown and empty
fullData = data.drop(data[data['StageGroup'].isnull()].index)
data = data.drop(data[data['StageGroup'] != 1].index)
len(data)
# Out:
# 1137

# %%
index_list = [
    'Total',
    'Age of Diagnosis',
    '    <=29',
    '    30-44',
    '    45-59',
    '    60-74',
    '    >=75',
    'Nationality',
    '    Estonian',
    '    Other',
    'Educational Level',
    '    Basic&Primary',
    '    Secondary',
    '    Secondary_vocational',
    '    University&higher',
    'Marital Status',
    '    Married',
    '    Divorced',
    '    Widow',
    '    Single',
    'Region of residence',
    '    South',
    '    North-East',
    '    Central',
    '    West',
    '    North',
    'Tumor Morphology',
    '    SCC',
    '    AC',
    '    Other',
]

# %%
table = {
    '2007-2010':[
        len(data[data['Period']=='2007-2010']),
        '',
        len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='<= 29')]),
        len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='30-44')]),
        len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='45-59')]),
        len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='60-74')]),
        len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='>= 75')]),
        '',
        len(data[(data['Period']=='2007-2010') & (data['Nationality']=='Estonian')]),
        len(data[(data['Period']=='2007-2010') & (data['Nationality']=='Other')]),
        '',
        len(data[(data['Period']=='2007-2010') & (data['Education']=='Basic&Primary')]),
        len(data[(data['Period']=='2007-2010') & (data['Education']=='Secondary')]),
        len(data[(data['Period']=='2007-2010') & (data['Education']=='Secondary_vocational')]),
        len(data[(data['Period']=='2007-2010') & (data['Education']=='University&higher')]),
        '',
        len(data[(data['Period']=='2007-2010') & (data['Marital Status']=='married')]),
        len(data[(data['Period']=='2007-2010') & (data['Marital Status']=='divorced')]),
        len(data[(data['Period']=='2007-2010') & (data['Marital Status']=='widow')]),
        len(data[(data['Period']=='2007-2010') & (data['Marital Status']=='single')]),
        '',
        len(data[(data['Period']=='2007-2010') & (data['Residence']=='South')]),
        len(data[(data['Period']=='2007-2010') & (data['Residence']=='North-East')]),
        len(data[(data['Period']=='2007-2010') & (data['Residence']=='Central')]),
        len(data[(data['Period']=='2007-2010') & (data['Residence']=='West')]),
        len(data[(data['Period']=='2007-2010') & (data['Residence']=='North')]),
        '',
        len(data[(data['Period']=='2007-2010') & (data['CodeGroup']=='SCC')]),
        len(data[(data['Period']=='2007-2010') & (data['CodeGroup']=='AC')]),
        len(data[(data['Period']=='2007-2010') & (data['CodeGroup']=='Other')]),
    ],
    '2007-2010, %':[
        get_pretty_pecent(len(data[data['Period']=='2007-2010']), len(fullData[fullData['Period']=='2007-2010'])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='<= 29')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['AgeGroup']=='<= 29')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='30-44')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['AgeGroup']=='30-44')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='45-59')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['AgeGroup']=='45-59')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='60-74')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['AgeGroup']=='60-74')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='>= 75')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['AgeGroup']=='>= 75')])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Nationality']=='Estonian')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Nationality']=='Estonian')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Nationality']=='Other')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Nationality']=='Other')])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Education']=='Basic&Primary')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Education']=='Basic&Primary')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Education']=='Secondary')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Education']=='Secondary')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Education']=='Secondary_vocational')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Education']=='Secondary_vocational')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Education']=='University&higher')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Education']=='University&higher')])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Marital Status']=='married')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Marital Status']=='married')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Marital Status']=='divorced')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Marital Status']=='divorced')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Marital Status']=='widow')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Marital Status']=='widow')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Marital Status']=='single')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Marital Status']=='single')])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Residence']=='South')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Residence']=='South')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Residence']=='North-East')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Residence']=='North-East')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Residence']=='Central')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Residence']=='Central')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Residence']=='West')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Residence']=='West')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Residence']=='North')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Residence']=='North')])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['CodeGroup']=='SCC')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['CodeGroup']=='SCC')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['CodeGroup']=='AC')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['CodeGroup']=='AC')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['CodeGroup']=='Other')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['CodeGroup']=='Other')])),
    ],
    ######## 2011-2014
 '2011-2014':[
        len(data[data['Period']=='2011-2014']),
        '',
        len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='<= 29')]),
        len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='30-44')]),
        len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='45-59')]),
        len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='60-74')]),
        len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='>= 75')]),
        '',
        len(data[(data['Period']=='2011-2014') & (data['Nationality']=='Estonian')]),
        len(data[(data['Period']=='2011-2014') & (data['Nationality']=='Other')]),
        '',
        len(data[(data['Period']=='2011-2014') & (data['Education']=='Basic&Primary')]),
        len(data[(data['Period']=='2011-2014') & (data['Education']=='Secondary')]),
        len(data[(data['Period']=='2011-2014') & (data['Education']=='Secondary_vocational')]),
        len(data[(data['Period']=='2011-2014') & (data['Education']=='University&higher')]),
        '',
        len(data[(data['Period']=='2011-2014') & (data['Marital Status']=='married')]),
        len(data[(data['Period']=='2011-2014') & (data['Marital Status']=='divorced')]),
        len(data[(data['Period']=='2011-2014') & (data['Marital Status']=='widow')]),
        len(data[(data['Period']=='2011-2014') & (data['Marital Status']=='single')]),
        '',
        len(data[(data['Period']=='2011-2014') & (data['Residence']=='South')]),
        len(data[(data['Period']=='2011-2014') & (data['Residence']=='North-East')]),
        len(data[(data['Period']=='2011-2014') & (data['Residence']=='Central')]),
        len(data[(data['Period']=='2011-2014') & (data['Residence']=='West')]),
        len(data[(data['Period']=='2011-2014') & (data['Residence']=='North')]),
        '',
        len(data[(data['Period']=='2011-2014') & (data['CodeGroup']=='SCC')]),
        len(data[(data['Period']=='2011-2014') & (data['CodeGroup']=='AC')]),
        len(data[(data['Period']=='2011-2014') & (data['CodeGroup']=='Other')]),
    ],
    '2011-2014, %':[
        get_pretty_pecent(len(data[data['Period']=='2011-2014']), len(fullData[fullData['Period']=='2011-2014'])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='<= 29')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['AgeGroup']=='<= 29')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='30-44')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['AgeGroup']=='30-44')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='45-59')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['AgeGroup']=='45-59')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='60-74')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['AgeGroup']=='60-74')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='>= 75')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['AgeGroup']=='>= 75')])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Nationality']=='Estonian')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Nationality']=='Estonian')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Nationality']=='Other')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Nationality']=='Other')])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Education']=='Basic&Primary')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Education']=='Basic&Primary')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Education']=='Secondary')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Education']=='Secondary')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Education']=='Secondary_vocational')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Education']=='Secondary_vocational')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Education']=='University&higher')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Education']=='University&higher')])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Marital Status']=='married')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Marital Status']=='married')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Marital Status']=='divorced')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Marital Status']=='divorced')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Marital Status']=='widow')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Marital Status']=='widow')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Marital Status']=='single')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Marital Status']=='single')])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Residence']=='South')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Residence']=='South')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Residence']=='North-East')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Residence']=='North-East')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Residence']=='Central')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Residence']=='Central')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Residence']=='West')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Residence']=='West')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Residence']=='North')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Residence']=='North')])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['CodeGroup']=='SCC')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['CodeGroup']=='SCC')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['CodeGroup']=='AC')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['CodeGroup']=='AC')])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['CodeGroup']=='Other')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['CodeGroup']=='Other')])),
    ],
    ########## 2015-2018
 '2015-2018':[
        len(data[data['Period']=='2015-2018']),
        '',
        len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='<= 29')]),
        len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='30-44')]),
        len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='45-59')]),
        len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='60-74')]),
        len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='>= 75')]),
        '',
        len(data[(data['Period']=='2015-2018') & (data['Nationality']=='Estonian')]),
        len(data[(data['Period']=='2015-2018') & (data['Nationality']=='Other')]),
        '',
        len(data[(data['Period']=='2015-2018') & (data['Education']=='Basic&Primary')]),
        len(data[(data['Period']=='2015-2018') & (data['Education']=='Secondary')]),
        len(data[(data['Period']=='2015-2018') & (data['Education']=='Secondary_vocational')]),
        len(data[(data['Period']=='2015-2018') & (data['Education']=='University&higher')]),
        '',
        len(data[(data['Period']=='2015-2018') & (data['Marital Status']=='married')]),
        len(data[(data['Period']=='2015-2018') & (data['Marital Status']=='divorced')]),
        len(data[(data['Period']=='2015-2018') & (data['Marital Status']=='widow')]),
        len(data[(data['Period']=='2015-2018') & (data['Marital Status']=='single')]),
        '',
        len(data[(data['Period']=='2015-2018') & (data['Residence']=='South')]),
        len(data[(data['Period']=='2015-2018') & (data['Residence']=='North-East')]),
        len(data[(data['Period']=='2015-2018') & (data['Residence']=='Central')]),
        len(data[(data['Period']=='2015-2018') & (data['Residence']=='West')]),
        len(data[(data['Period']=='2015-2018') & (data['Residence']=='North')]),
        '',
        len(data[(data['Period']=='2015-2018') & (data['CodeGroup']=='SCC')]),
        len(data[(data['Period']=='2015-2018') & (data['CodeGroup']=='AC')]),
        len(data[(data['Period']=='2015-2018') & (data['CodeGroup']=='Other')]),
    ],
    '2015-2018, %':[
        get_pretty_pecent(len(data[data['Period']=='2015-2018']), len(fullData[fullData['Period']=='2015-2018'])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='<= 29')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['AgeGroup']=='<= 29')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='30-44')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['AgeGroup']=='30-44')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='45-59')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['AgeGroup']=='45-59')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='60-74')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['AgeGroup']=='60-74')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='>= 75')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['AgeGroup']=='>= 75')])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Nationality']=='Estonian')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Nationality']=='Estonian')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Nationality']=='Other')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Nationality']=='Other')])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Education']=='Basic&Primary')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Education']=='Basic&Primary')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Education']=='Secondary')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Education']=='Secondary')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Education']=='Secondary_vocational')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Education']=='Secondary_vocational')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Education']=='University&higher')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Education']=='University&higher')])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Marital Status']=='married')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Marital Status']=='married')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Marital Status']=='divorced')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Marital Status']=='divorced')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Marital Status']=='widow')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Marital Status']=='widow')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Marital Status']=='single')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Marital Status']=='single')])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Residence']=='South')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Residence']=='South')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Residence']=='North-East')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Residence']=='North-East')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Residence']=='Central')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Residence']=='Central')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Residence']=='West')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Residence']=='West')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Residence']=='North')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Residence']=='North')])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['CodeGroup']=='SCC')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['CodeGroup']=='SCC')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['CodeGroup']=='AC')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['CodeGroup']=='AC')])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['CodeGroup']=='Other')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['CodeGroup']=='Other')])),
    ]
}

# %%
df = pd.DataFrame(table, index=index_list)
print(df)
# Out:
#                          2007-2010 2007-2010, % 2011-2014 2011-2014, %  \
# Total                          384        55.73       421        63.21
# Age of Diagnosis
#     <=29                         6        26.09         8         40.0
#     30-44                       59        34.71        62         40.0
#     45-59                      149        55.19       142        60.68
#     60-74                      103        70.55       147        79.03
#     >=75                        67        83.75        62        87.32
# Nationality
#     Estonian                   259        53.62       275        63.07
#     Other                      120         59.7       143        63.56
# Educational Level
#     Basic&Primary               99        67.35        98        74.24
#     Secondary                  139        52.45       155        63.01
#     Secondary_vocational        56        53.33        78        55.71
# ...

# %%
df2 = df.assign(Changes=[
    round(df['2015-2018, %'].values[0] - df['2007-2010, %'].values[0], 2), 
    '', 
    round(df['2015-2018, %'].values[2] - df['2007-2010, %'].values[2], 2), 
    round(df['2015-2018, %'].values[3] - df['2007-2010, %'].values[3], 2), 
    round(df['2015-2018, %'].values[4] - df['2007-2010, %'].values[4], 2), 
    round(df['2015-2018, %'].values[5] - df['2007-2010, %'].values[5], 2), 
    round(df['2015-2018, %'].values[6] - df['2007-2010, %'].values[6], 2), 
    '', 
    round(df['2015-2018, %'].values[8] - df['2007-2010, %'].values[8], 2), 
    round(df['2015-2018, %'].values[9] - df['2007-2010, %'].values[9], 2), 
    '', 
    round(df['2015-2018, %'].values[11] - df['2007-2010, %'].values[11], 2), 
    round(df['2015-2018, %'].values[12] - df['2007-2010, %'].values[12], 2), 
    round(df['2015-2018, %'].values[13] - df['2007-2010, %'].values[13], 2), 
    round(df['2015-2018, %'].values[14] - df['2007-2010, %'].values[14], 2), 
    '', 
    round(df['2015-2018, %'].values[16] - df['2007-2010, %'].values[16], 2), 
    round(df['2015-2018, %'].values[17] - df['2007-2010, %'].values[17], 2), 
    round(df['2015-2018, %'].values[18] - df['2007-2010, %'].values[18], 2), 
    round(df['2015-2018, %'].values[19] - df['2007-2010, %'].values[19], 2), 
    '', 
    round(df['2015-2018, %'].values[21] - df['2007-2010, %'].values[21], 2), 
    round(df['2015-2018, %'].values[22] - df['2007-2010, %'].values[22], 2), 
    round(df['2015-2018, %'].values[23] - df['2007-2010, %'].values[23], 2), 
    round(df['2015-2018, %'].values[24] - df['2007-2010, %'].values[24], 2), 
    round(df['2015-2018, %'].values[25] - df['2007-2010, %'].values[25], 2), 
    '', 
    round(df['2015-2018, %'].values[27] - df['2007-2010, %'].values[27], 2), 
    round(df['2015-2018, %'].values[28] - df['2007-2010, %'].values[28], 2), 
    round(df['2015-2018, %'].values[29] - df['2007-2010, %'].values[29], 2), 
])

# %%
print(df2)
# Out:
#                          2007-2010 2007-2010, % 2011-2014 2011-2014, %  \
# Total                          384        55.73       421        63.21
# Age of Diagnosis
#     <=29                         6        26.09         8         40.0
#     30-44                       59        34.71        62         40.0
#     45-59                      149        55.19       142        60.68
#     60-74                      103        70.55       147        79.03
#     >=75                        67        83.75        62        87.32
# Nationality
#     Estonian                   259        53.62       275        63.07
#     Other                      120         59.7       143        63.56
# Educational Level
#     Basic&Primary               99        67.35        98        74.24
#     Secondary                  139        52.45       155        63.01
#     Secondary_vocational        56        53.33        78        55.71
# ...

# %%
# drop second period
fullData = fullData.drop(fullData[fullData['Period']=='2011-2014'].index)

# %%
df3 = df2.assign(PiValue=[
    get_chi(
        fullData['Period'],
        fullData['StageGroup']
    ), 
    '', 
    get_chi(
        fullData[fullData['AgeGroup']=='<= 29']['Period'],
        fullData[fullData['AgeGroup']=='<= 29']['StageGroup']
    ),
    get_chi(
        fullData[fullData['AgeGroup']=='30-44']['Period'],
        fullData[fullData['AgeGroup']=='30-44']['StageGroup']
    ), 
    get_chi(
        fullData[fullData['AgeGroup']=='45-59']['Period'],
        fullData[fullData['AgeGroup']=='45-59']['StageGroup']
    ),
    get_chi(
        fullData[fullData['AgeGroup']=='60-74']['Period'],
        fullData[fullData['AgeGroup']=='60-74']['StageGroup']
    ),
    get_chi(
        fullData[fullData['AgeGroup']=='>= 75']['Period'],
        fullData[fullData['AgeGroup']=='>= 75']['StageGroup']
    ),
    '', 
    get_chi(
        fullData[fullData['Nationality']=='Estonian']['Period'],
        fullData[fullData['Nationality']=='Estonian']['StageGroup']
    ), 
    get_chi(
        fullData[fullData['Nationality']=='Other']['Period'],
        fullData[fullData['Nationality']=='Other']['StageGroup']
    ),
    '', 
    get_chi(
        fullData[fullData['Education']=='Basic&Primary']['Period'],
        fullData[fullData['Education']=='Basic&Primary']['StageGroup']
    ),
    get_chi(
        fullData[fullData['Education']=='Secondary']['Period'],
        fullData[fullData['Education']=='Secondary']['StageGroup']
    ), 
    get_chi(
        fullData[fullData['Education']=='Secondary_vocational']['Period'],
        fullData[fullData['Education']=='Secondary_vocational']['StageGroup']
    ),
    get_chi(
        fullData[fullData['Education']=='University&higher']['Period'],
        fullData[fullData['Education']=='University&higher']['StageGroup']
    ), 
    '', 
    get_chi(
        fullData[fullData['Marital Status']=='married']['Period'],
        fullData[fullData['Marital Status']=='married']['StageGroup']
    ),  
    get_chi(
        fullData[fullData['Marital Status']=='divorced']['Period'],
        fullData[fullData['Marital Status']=='divorced']['StageGroup']
    ),
    get_chi(
        fullData[fullData['Marital Status']=='widow']['Period'],
        fullData[fullData['Marital Status']=='widow']['StageGroup']
    ), 
    get_chi(
        fullData[fullData['Marital Status']=='single']['Period'],
        fullData[fullData['Marital Status']=='single']['StageGroup']
    ), 
    '', 
    get_chi(
        fullData[fullData['Residence']=='South']['Period'],
        fullData[fullData['Residence']=='South']['StageGroup']
    ), 
    get_chi(
        fullData[fullData['Residence']=='North-East']['Period'],
        fullData[fullData['Residence']=='North-East']['StageGroup']
    ),
    get_chi(
        fullData[fullData['Residence']=='Central']['Period'],
        fullData[fullData['Residence']=='Central']['StageGroup']
    ),
    get_chi(
        fullData[fullData['Residence']=='West']['Period'],
        fullData[fullData['Residence']=='West']['StageGroup']
    ),
    get_chi(
        fullData[fullData['Residence']=='North']['Period'],
        fullData[fullData['Residence']=='North']['StageGroup']
    ), 
    '', 
    get_chi(
        fullData[fullData['CodeGroup']=='SCC']['Period'],
        fullData[fullData['CodeGroup']=='SCC']['StageGroup']
    ), 
    get_chi(
        fullData[fullData['CodeGroup']=='AC']['Period'],
        fullData[fullData['CodeGroup']=='AC']['StageGroup']
    ), 
    get_chi(
        fullData[fullData['CodeGroup']=='Other']['Period'],
        fullData[fullData['CodeGroup']=='Other']['StageGroup']
    ),
])

# %%
print(df3)
# Out:
#                          2007-2010 2007-2010, % 2011-2014 2011-2014, %  \
# Total                          384        55.73       421        63.21
# Age of Diagnosis
#     <=29                         6        26.09         8         40.0
#     30-44                       59        34.71        62         40.0
#     45-59                      149        55.19       142        60.68
#     60-74                      103        70.55       147        79.03
#     >=75                        67        83.75        62        87.32
# Nationality
#     Estonian                   259        53.62       275        63.07
#     Other                      120         59.7       143        63.56
# Educational Level
#     Basic&Primary               99        67.35        98        74.24
#     Secondary                  139        52.45       155        63.01
#     Secondary_vocational        56        53.33        78        55.71
# ...

# %%
df3.to_csv('table2.csv', index=True)
