# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

# %%
data = pd.read_csv("./prepared_data.csv", index_col=False)

# %%
def get_pretty_pecent(a, b):
    return round(100 * float(a)/float(b), 2)
    #return "{:.2%}".format(a/b)
def get_chi(a, b):
    ctab = pd.crosstab(a, b)
    #print(ctab)
    chi2, p, dof, ex = chi2_contingency(ctab)
    if (p < 0.0005):
        p = '<0.0005';
    return p

# %%
#drop unknown and empty
fullData = data.drop(data[data['StageGroup'].isnull()].index)
data = data.drop(data[data['StageGroup'] != 1].index)
len(data)
# Out:
# 1137

# %%
index_list = [
    'Total',
    'Age of Diagnosis',
    '    <=29',
    '    30-44',
    '    45-59',
    '    60-74',
    '    >=75',
    'Nationality',
    '    Estonian',
    '    Other',
    'Educational Level',
    '    Basic&Primary',
    '    Secondary',
    '    Secondary_vocational',
    '    University&higher',
    'Marital Status',
    '    Married',
    '    Divorced',
    '    Widow',
    '    Single',
    'Region of residence',
    '    South',
    '    North-East',
    '    Central',
    '    West',
    '    North',
    'Tumor Morphology',
    '    SCC',
    '    AC',
]

# %%
table = {
    '2007-2010':[
        len(data[data['Period']=='2007-2010']),
        '',
        len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='<= 29')]),
        len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='30-44')]),
        len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='45-59')]),
        len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='60-74')]),
        len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='>= 75')]),
        '',
        len(data[(data['Period']=='2007-2010') & (data['Nationality']=='Estonian')]),
        len(data[(data['Period']=='2007-2010') & (data['Nationality']=='Other')]),
        '',
        len(data[(data['Period']=='2007-2010') & (data['Education']=='Basic&Primary')]),
        len(data[(data['Period']=='2007-2010') & (data['Education']=='Secondary')]),
        len(data[(data['Period']=='2007-2010') & (data['Education']=='Secondary_vocational')]),
        len(data[(data['Period']=='2007-2010') & (data['Education']=='University&higher')]),
        '',
        len(data[(data['Period']=='2007-2010') & (data['Marital Status']=='married')]),
        len(data[(data['Period']=='2007-2010') & (data['Marital Status']=='divorced')]),
        len(data[(data['Period']=='2007-2010') & (data['Marital Status']=='widow')]),
        len(data[(data['Period']=='2007-2010') & (data['Marital Status']=='single')]),
        '',
        len(data[(data['Period']=='2007-2010') & (data['Residence']=='South')]),
        len(data[(data['Period']=='2007-2010') & (data['Residence']=='North-East')]),
        len(data[(data['Period']=='2007-2010') & (data['Residence']=='Central')]),
        len(data[(data['Period']=='2007-2010') & (data['Residence']=='West')]),
        len(data[(data['Period']=='2007-2010') & (data['Residence']=='North')]),
        '',
        len(data[(data['Period']=='2007-2010') & (data['CodeGroup']=='SCC')]),
        len(data[(data['Period']=='2007-2010') & (data['CodeGroup']=='AC')]),
    ],
    '2007-2010, %':[
        get_pretty_pecent(len(data[data['Period']=='2007-2010']), len(fullData[fullData['Period']=='2007-2010'])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='<= 29')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['AgeGroup']=='<= 29')])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='30-44')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='45-59')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='60-74')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['AgeGroup']=='>= 75')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['AgeGroup'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Nationality']=='Estonian')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Nationality'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Nationality']=='Other')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Nationality'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Education']=='Basic&Primary')]), len(fullData[(data['Period']=='2007-2010') & (fullData['Education'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Education']=='Secondary')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Education'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Education']=='Secondary_vocational')]), len(fullData[(data['Period']=='2007-2010') & (fullData['Education'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Education']=='University&higher')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Education'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Marital Status']=='married')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Marital Status'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Marital Status']=='divorced')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Marital Status'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Marital Status']=='widow')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Marital Status'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Marital Status']=='single')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Marital Status'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Residence']=='South')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Residence']=='North-East')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Residence']=='Central')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Residence']=='West')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['Residence']=='North')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['Residence'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['CodeGroup']=='SCC')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['CodeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2007-2010') & (data['CodeGroup']=='AC')]), len(fullData[(fullData['Period']=='2007-2010') & (fullData['CodeGroup'].notna())])),
    ],
    ######## 2011-2014
 '2011-2014':[
        len(data[data['Period']=='2011-2014']),
        '',
        len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='<= 29')]),
        len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='30-44')]),
        len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='45-59')]),
        len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='60-74')]),
        len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='>= 75')]),
        '',
        len(data[(data['Period']=='2011-2014') & (data['Nationality']=='Estonian')]),
        len(data[(data['Period']=='2011-2014') & (data['Nationality']=='Other')]),
        '',
        len(data[(data['Period']=='2011-2014') & (data['Education']=='Basic&Primary')]),
        len(data[(data['Period']=='2011-2014') & (data['Education']=='Secondary')]),
        len(data[(data['Period']=='2011-2014') & (data['Education']=='Secondary_vocational')]),
        len(data[(data['Period']=='2011-2014') & (data['Education']=='University&higher')]),
        '',
        len(data[(data['Period']=='2011-2014') & (data['Marital Status']=='married')]),
        len(data[(data['Period']=='2011-2014') & (data['Marital Status']=='divorced')]),
        len(data[(data['Period']=='2011-2014') & (data['Marital Status']=='widow')]),
        len(data[(data['Period']=='2011-2014') & (data['Marital Status']=='single')]),
        '',
        len(data[(data['Period']=='2011-2014') & (data['Residence']=='South')]),
        len(data[(data['Period']=='2011-2014') & (data['Residence']=='North-East')]),
        len(data[(data['Period']=='2011-2014') & (data['Residence']=='Central')]),
        len(data[(data['Period']=='2011-2014') & (data['Residence']=='West')]),
        len(data[(data['Period']=='2011-2014') & (data['Residence']=='North')]),
        '',
        len(data[(data['Period']=='2011-2014') & (data['CodeGroup']=='SCC')]),
        len(data[(data['Period']=='2011-2014') & (data['CodeGroup']=='AC')]),
    ],
    '2011-2014, %':[
        get_pretty_pecent(len(data[data['Period']=='2011-2014']), len(fullData[fullData['Period']=='2011-2014'])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='<= 29')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='30-44')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='45-59')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='60-74')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['AgeGroup']=='>= 75')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['AgeGroup'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Nationality']=='Estonian')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Nationality'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Nationality']=='Other')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Nationality'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Education']=='Basic&Primary')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Education'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Education']=='Secondary')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Education'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Education']=='Secondary_vocational')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Education'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Education']=='University&higher')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Education'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Marital Status']=='married')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Marital Status'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Marital Status']=='divorced')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Marital Status'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Marital Status']=='widow')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Marital Status'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Marital Status']=='single')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Marital Status'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Residence']=='South')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Residence']=='North-East')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Residence']=='Central')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Residence']=='West')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['Residence']=='North')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['Residence'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['CodeGroup']=='SCC')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['CodeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2011-2014') & (data['CodeGroup']=='AC')]), len(fullData[(fullData['Period']=='2011-2014') & (fullData['CodeGroup'].notna())])),
    ],
    ########## 2015-2018
 '2015-2018':[
        len(data[data['Period']=='2015-2018']),
        '',
        len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='<= 29')]),
        len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='30-44')]),
        len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='45-59')]),
        len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='60-74')]),
        len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='>= 75')]),
        '',
        len(data[(data['Period']=='2015-2018') & (data['Nationality']=='Estonian')]),
        len(data[(data['Period']=='2015-2018') & (data['Nationality']=='Other')]),
        '',
        len(data[(data['Period']=='2015-2018') & (data['Education']=='Basic&Primary')]),
        len(data[(data['Period']=='2015-2018') & (data['Education']=='Secondary')]),
        len(data[(data['Period']=='2015-2018') & (data['Education']=='Secondary_vocational')]),
        len(data[(data['Period']=='2015-2018') & (data['Education']=='University&higher')]),
        '',
        len(data[(data['Period']=='2015-2018') & (data['Marital Status']=='married')]),
        len(data[(data['Period']=='2015-2018') & (data['Marital Status']=='divorced')]),
        len(data[(data['Period']=='2015-2018') & (data['Marital Status']=='widow')]),
        len(data[(data['Period']=='2015-2018') & (data['Marital Status']=='single')]),
        '',
        len(data[(data['Period']=='2015-2018') & (data['Residence']=='South')]),
        len(data[(data['Period']=='2015-2018') & (data['Residence']=='North-East')]),
        len(data[(data['Period']=='2015-2018') & (data['Residence']=='Central')]),
        len(data[(data['Period']=='2015-2018') & (data['Residence']=='West')]),
        len(data[(data['Period']=='2015-2018') & (data['Residence']=='North')]),
        '',
        len(data[(data['Period']=='2015-2018') & (data['CodeGroup']=='SCC')]),
        len(data[(data['Period']=='2015-2018') & (data['CodeGroup']=='AC')]),
    ],
    '2015-2018, %':[
        get_pretty_pecent(len(data[data['Period']=='2015-2018']), len(fullData[fullData['Period']=='2015-2018'])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='<= 29')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='30-44')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='45-59')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='60-74')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['AgeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['AgeGroup']=='>= 75')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['AgeGroup'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Nationality']=='Estonian')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Nationality'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Nationality']=='Other')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Nationality'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Education']=='Basic&Primary')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Education'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Education']=='Secondary')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Education'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Education']=='Secondary_vocational')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Education'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Education']=='University&higher')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Education'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Marital Status']=='married')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Marital Status'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Marital Status']=='divorced')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Marital Status'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Marital Status']=='widow')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Marital Status'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Marital Status']=='single')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Marital Status'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Residence']=='South')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Residence']=='North-East')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Residence']=='Central')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Residence']=='West')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Residence'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['Residence']=='North')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['Residence'].notna())])),
        '',
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['CodeGroup']=='SCC')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['CodeGroup'].notna())])),
        get_pretty_pecent(len(data[(data['Period']=='2015-2018') & (data['CodeGroup']=='AC')]), len(fullData[(fullData['Period']=='2015-2018') & (fullData['CodeGroup'].notna())])),
    ]
}

# %%
df = pd.DataFrame(table, index=index_list)
print(df)
# Out:
#                          2007-2010 2007-2010, % 2011-2014 2011-2014, %  \
# Total                          384        55.73       421        63.21
# Age of Diagnosis
#     <=29                         6        26.09         8          1.2
#     30-44                       59         8.56        62         9.31
#     45-59                      149        21.63       142        21.32
#     60-74                      103        14.95       147        22.07
#     >=75                        67         9.72        62         9.31
# Nationality
#     Estonian                   259        37.87       275         41.6
#     Other                      120        17.54       143        21.63
# Educational Level
#     Basic&Primary               99        29.29        98        15.68
#     Secondary                  139        22.31       155         24.8
#     Secondary_vocational        56        16.57        78        12.48
# ...

# %%
df2 = df.assign(Changes=[
    round(df['2015-2018, %'].values[0] - df['2007-2010, %'].values[0], 2), 
    '', 
    round(df['2015-2018, %'].values[2] - df['2007-2010, %'].values[2], 2), 
    round(df['2015-2018, %'].values[3] - df['2007-2010, %'].values[3], 2), 
    round(df['2015-2018, %'].values[4] - df['2007-2010, %'].values[4], 2), 
    round(df['2015-2018, %'].values[5] - df['2007-2010, %'].values[5], 2), 
    round(df['2015-2018, %'].values[6] - df['2007-2010, %'].values[6], 2), 
    '', 
    round(df['2015-2018, %'].values[8] - df['2007-2010, %'].values[8], 2), 
    round(df['2015-2018, %'].values[9] - df['2007-2010, %'].values[9], 2), 
    '', 
    round(df['2015-2018, %'].values[11] - df['2007-2010, %'].values[11], 2), 
    round(df['2015-2018, %'].values[12] - df['2007-2010, %'].values[12], 2), 
    round(df['2015-2018, %'].values[13] - df['2007-2010, %'].values[13], 2), 
    round(df['2015-2018, %'].values[14] - df['2007-2010, %'].values[14], 2), 
    '', 
    round(df['2015-2018, %'].values[16] - df['2007-2010, %'].values[16], 2), 
    round(df['2015-2018, %'].values[17] - df['2007-2010, %'].values[17], 2), 
    round(df['2015-2018, %'].values[18] - df['2007-2010, %'].values[18], 2), 
    round(df['2015-2018, %'].values[19] - df['2007-2010, %'].values[19], 2), 
    '', 
    round(df['2015-2018, %'].values[21] - df['2007-2010, %'].values[21], 2), 
    round(df['2015-2018, %'].values[22] - df['2007-2010, %'].values[22], 2), 
    round(df['2015-2018, %'].values[23] - df['2007-2010, %'].values[23], 2), 
    round(df['2015-2018, %'].values[24] - df['2007-2010, %'].values[24], 2), 
    round(df['2015-2018, %'].values[25] - df['2007-2010, %'].values[25], 2), 
    '', 
    round(df['2015-2018, %'].values[27] - df['2007-2010, %'].values[27], 2), 
    round(df['2015-2018, %'].values[28] - df['2007-2010, %'].values[28], 2), 
])

# %%
print(df2)
# Out:
#                          2007-2010 2007-2010, % 2011-2014 2011-2014, %  \
# Total                          384        55.73       421        63.21
# Age of Diagnosis
#     <=29                         6        26.09         8          1.2
#     30-44                       59         8.56        62         9.31
#     45-59                      149        21.63       142        21.32
#     60-74                      103        14.95       147        22.07
#     >=75                        67         9.72        62         9.31
# Nationality
#     Estonian                   259        37.87       275         41.6
#     Other                      120        17.54       143        21.63
# Educational Level
#     Basic&Primary               99        29.29        98        15.68
#     Secondary                  139        22.31       155         24.8
#     Secondary_vocational        56        16.57        78        12.48
# ...

# %%
df3 = df2.assign(PiValue=[
    get_chi(
        fullData['Year'],
        fullData['StageGroup']
    ), 
    '', 
    get_chi(
        fullData[fullData['AgeGroup']=='<= 29']['Year'],
        fullData[fullData['AgeGroup']=='<= 29']['StageGroup']
    ),
    get_chi(
        fullData[fullData['AgeGroup']=='30-44']['Year'],
        fullData[fullData['AgeGroup']=='30-44']['StageGroup']
    ), 
    get_chi(
        fullData[fullData['AgeGroup']=='45-59']['Year'],
        fullData[fullData['AgeGroup']=='45-59']['StageGroup']
    ),
    get_chi(
        fullData[fullData['AgeGroup']=='60-74']['Year'],
        fullData[fullData['AgeGroup']=='60-74']['StageGroup']
    ),
    get_chi(
        fullData[fullData['AgeGroup']=='>= 75']['Year'],
        fullData[fullData['AgeGroup']=='>= 75']['StageGroup']
    ),
    '', 
    get_chi(
        fullData[fullData['Nationality']=='Estonian']['Year'],
        fullData[fullData['Nationality']=='Estonian']['StageGroup']
    ), 
    get_chi(
        fullData[fullData['Nationality']=='Other']['Year'],
        fullData[fullData['Nationality']=='Other']['StageGroup']
    ),
    '', 
    get_chi(
        fullData[fullData['Education']=='Basic&Primary']['Year'],
        fullData[fullData['Education']=='Basic&Primary']['StageGroup']
    ),
    get_chi(
        fullData[fullData['Education']=='Secondary']['Year'],
        fullData[fullData['Education']=='Secondary']['StageGroup']
    ), 
    get_chi(
        fullData[fullData['Education']=='Secondary_vocational']['Year'],
        fullData[fullData['Education']=='Secondary_vocational']['StageGroup']
    ),
    get_chi(
        fullData[fullData['Education']=='University&higher']['Year'],
        fullData[fullData['Education']=='University&higher']['StageGroup']
    ), 
    '', 
    get_chi(
        fullData[fullData['Marital Status']=='married']['Year'],
        fullData[fullData['Marital Status']=='married']['StageGroup']
    ),  
    get_chi(
        fullData[fullData['Marital Status']=='divorced']['Year'],
        fullData[fullData['Marital Status']=='divorced']['StageGroup']
    ),
    get_chi(
        fullData[fullData['Marital Status']=='widow']['Year'],
        fullData[fullData['Marital Status']=='widow']['StageGroup']
    ), 
    get_chi(
        fullData[fullData['Marital Status']=='single']['Year'],
        fullData[fullData['Marital Status']=='single']['StageGroup']
    ), 
    '', 
    get_chi(
        fullData[fullData['Residence']=='South']['Year'],
        fullData[fullData['Residence']=='South']['StageGroup']
    ), 
    get_chi(
        fullData[fullData['Residence']=='North-East']['Year'],
        fullData[fullData['Residence']=='North-East']['StageGroup']
    ),
    get_chi(
        fullData[fullData['Residence']=='Central']['Year'],
        fullData[fullData['Residence']=='Central']['StageGroup']
    ),
    get_chi(
        fullData[fullData['Residence']=='West']['Year'],
        fullData[fullData['Residence']=='West']['StageGroup']
    ),
    get_chi(
        fullData[fullData['Residence']=='North']['Year'],
        fullData[fullData['Residence']=='North']['StageGroup']
    ), 
    '', 
    get_chi(
        fullData[fullData['CodeGroup']=='SCC']['Year'],
        fullData[fullData['CodeGroup']=='SCC']['StageGroup']
    ), 
    get_chi(
        fullData[fullData['CodeGroup']=='AC']['Year'],
        fullData[fullData['CodeGroup']=='AC']['StageGroup']
    ), 
])

# %%
print(df3)
# Out:
#                          2007-2010 2007-2010, % 2011-2014 2011-2014, %  \
# Total                          384        55.73       421        63.21
# Age of Diagnosis
#     <=29                         6        26.09         8          1.2
#     30-44                       59         8.56        62         9.31
#     45-59                      149        21.63       142        21.32
#     60-74                      103        14.95       147        22.07
#     >=75                        67         9.72        62         9.31
# Nationality
#     Estonian                   259        37.87       275         41.6
#     Other                      120        17.54       143        21.63
# Educational Level
#     Basic&Primary               99        29.29        98        15.68
#     Secondary                  139        22.31       155         24.8
#     Secondary_vocational        56        16.57        78        12.48
# ...

# %%
df3.to_csv('table2.csv', index=True)
